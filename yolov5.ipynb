# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# /home/samantha/Desktop/Aryan_raj/Dubai_project/yolov5
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

from IPython.display import Image,clear_output
print("Setup Complete")
# Out:
# Setup Complete

# %%
# !python3 train.py --batch-size 20 --epochs 300 --data /home/samantha/Desktop/Aryan_raj/Dubai_project/archive/data.yaml --weights 'yolov5/yolov5s.pt' --device 0
# Out:
# train: weights=yolov5/yolov5s.pt, cfg=, data=/home/samantha/Desktop/Aryan_raj/Dubai_project/archive/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=20, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v7.0-59-gfdc35b1 Python-3.10.6 torch-1.12.1+cu102 CUDA:0 (NVIDIA TITAN X (Pascal), 12193MiB)
#
# ...

# %%
# !python3 detect.py --weights /home/samantha/Desktop/Aryan_raj/Dubai_project/yolov5/runs/train/exp3/weights/last.pt --img 640 --conf 0.25 --source /home/samantha/Desktop/Aryan_raj/Dubai_project/testvedio1.mp4
# Out:
# detect: weights=['/home/samantha/Desktop/Aryan_raj/Dubai_project/yolov5/runs/train/exp3/weights/last.pt'], source=/home/samantha/Desktop/Aryan_raj/Dubai_project/testvedio1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-59-gfdc35b1 Python-3.10.6 torch-1.12.1+cu102 CUDA:0 (NVIDIA TITAN X (Pascal), 12193MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/4900) /home/samantha/Desktop/Aryan_raj/Dubai_project/testvedio1.mp4: 384x640 1 pothole, 5.2ms
# video 1/1 (2/4900) /home/samantha/Desktop/Aryan_raj/Dubai_project/testvedio1.mp4: 384x640 1 pothole, 7.4ms
# ...

# %%
# !python3 detect.py --weights /home/samantha/Desktop/Aryan_raj/Dubai_project/yolov5/runs/train/exp3/weights/last.pt --img 640 --conf 0.25 --source /home/samantha/Desktop/Aryan_raj/Dubai_project/testvedio2.mp4
# Out:
# detect: weights=['/home/samantha/Desktop/Aryan_raj/Dubai_project/yolov5/runs/train/exp3/weights/last.pt'], source=/home/samantha/Desktop/Aryan_raj/Dubai_project/testvedio2.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-59-gfdc35b1 Python-3.10.6 torch-1.12.1+cu102 CUDA:0 (NVIDIA TITAN X (Pascal), 12193MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/1998) /home/samantha/Desktop/Aryan_raj/Dubai_project/testvedio2.mp4: 384x640 1 pothole, 5.5ms
# video 1/1 (2/1998) /home/samantha/Desktop/Aryan_raj/Dubai_project/testvedio2.mp4: 384x640 1 pothole, 5.8ms
# ...

# %%
# !python3 detect.py --weights /home/samantha/Desktop/Aryan_raj/Dubai_project/yolov5/runs/train/exp3/weights/last.pt --img 640 --conf 0.25 --source /home/samantha/Desktop/Aryan_raj/Dubai_project/testvedio3.mp4
# Out:
# detect: weights=['/home/samantha/Desktop/Aryan_raj/Dubai_project/yolov5/runs/train/exp3/weights/last.pt'], source=/home/samantha/Desktop/Aryan_raj/Dubai_project/testvedio3.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-59-gfdc35b1 Python-3.10.6 torch-1.12.1+cu102 CUDA:0 (NVIDIA TITAN X (Pascal), 12193MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/20671) /home/samantha/Desktop/Aryan_raj/Dubai_project/testvedio3.mp4: 384x640 1 pothole, 6.3ms
# video 1/1 (2/20671) /home/samantha/Desktop/Aryan_raj/Dubai_project/testvedio3.mp4: 384x640 1 pothole, 5.4ms
# ...
